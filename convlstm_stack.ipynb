# %%
import glob
import pandas as pd
from tensorflow import keras
import numpy as np
import os 
import matplotlib.pylab as plt
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.layers import TimeDistributed, Conv2D, Conv2DTranspose, MaxPooling2D, AveragePooling2D, BatchNormalization, concatenate, Input, ConvLSTM2D, Reshape, Conv3D, Flatten, LSTM, GRU, Dense,Dropout, Add
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, LearningRateScheduler
from tensorflow.keras.models import Sequential, load_model
from sklearn.utils import shuffle

# %%
# mean and standard deviation for train data 
mu = 13.262550318358528
std = 36.12859290913875

# %%
class DataGenerator(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, batch_size=32, dim=(120,120), n_channels=1, n_timesteps = 4, shuffle=True, augment_data = True,
                standardize = False):
        'Initialization'
        self.dim = dim
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.n_timesteps = n_timesteps 
        self.shuffle = shuffle
        self.augment_data = augment_data  
        self.standardize = standardize 
        self.on_epoch_end() 

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        list_IDs_temp = [self.list_IDs[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(list_IDs_temp)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, list_IDs_temp):
        'Generates data containing batch_size samples' 
        
        if self.augment_data == True:  # only augment data when training 
            # Initialization
            X = np.empty((self.batch_size*6, 120, 120, 4))
            y = np.empty((self.batch_size*6, 120, 120, 1)) 

            # Generate data
            for i, ID in enumerate(list_IDs_temp):
                data = np.load('./storage/precipitation/train/' + ID)
                # Store sample
                x_data = data[:,:,:4] 
                y_data = data[:,:,-1].reshape((120,120,1)) 
                
                X[i,] = x_data
                y[i] = y_data 
                
                # add 90 degrees rotation 
                X[i+self.batch_size,] = np.rot90(x_data)
                y[i+self.batch_size] = np.rot90(y_data)  
                
                # add 180 degrees rotation 
                X[i+self.batch_size*2,] = np.rot90(np.rot90(x_data)) 
                y[i+self.batch_size*2] = np.rot90(np.rot90(y_data)) 
                
                # add 270 degrees rotation 
                X[i+self.batch_size*3,] = np.rot90(np.rot90(np.rot90(x_data)))
                y[i+self.batch_size*3] = np.rot90(np.rot90(np.rot90(y_data)))  
                
                # add horizontal flip 
                X[i+self.batch_size*4,] = np.fliplr(x_data)
                y[i+self.batch_size*4] = np.fliplr(y_data) 
                
                # add vertical filp 
                X[i+self.batch_size*5,] = np.flipud(x_data) 
                y[i+self.batch_size*5] = np.flipud(y_data)
            
            # shuffle once more to make training harder 
            X,y = shuffle(X,y) 
            return (X, y)
        
        else: 
            # Initialization
            size = 20 
            X = np.empty((self.batch_size, 4, size, size, 36))
            y = np.empty((self.batch_size, size, size, 36)) 

            # Generate data
            for i, ID in enumerate(list_IDs_temp):
                data = np.load('./storage/precipitation/train/' + ID).astype(np.float32) 
                if self.standardize:  
                    data = (data - mu)/std
                # Store sample
                x_train = [] 
                y_train = [] 
                
                for timestep in range(4): 
                    for j in range(6): 
                        for k in range(6):  
                            x_train.append(data[size*j:size*(j+1),size*k:size*(k+1),timestep]) 
                            
                x_train = np.asarray(x_train)
                x_train = x_train.reshape((4,20,20,36)) 
                
                for j in range(6): 
                    for k in range(6):  
                        y_train.append(data[size*j:size*(j+1),size*k:size*(k+1),-1]) 
                    
                y_train = np.asarray(y_train) 
                y_train = y_train.reshape((20,20,36)) 
                
                X[i,] = x_train 
                y[i] = y_train
            
            #print(X[i].shape, y[i].shape)
                
            return X,y

# %%
def simple_rnn(): 
    inputs = Input((4,20,20,36)) 
    bn = BatchNormalization()(inputs)
    conv = ConvLSTM2D(40, 3, padding = 'same', return_sequences = True)(bn)
    bn = BatchNormalization()(conv) 
    conv = ConvLSTM2D(40, 3, padding = 'same', return_sequences = False)(bn)
    bn = BatchNormalization()(conv)  
    outputs = Conv2D(36, 1, padding = "same", activation = 'relu')(bn) 
    model = Model(inputs=inputs,outputs=outputs) 
    model.compile(loss='mae',optimizer='adam')
    return model

# %%
model = simple_rnn() 
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 4, 20, 20, 36)]   0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 4, 20, 20, 36)     144
# _________________________________________________________________
# conv_lst_m2d (ConvLSTM2D)    (None, 4, 20, 20, 40)     109600
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 4, 20, 20, 40)     160
# _________________________________________________________________
# conv_lst_m2d_1 (ConvLSTM2D)  (None, 20, 20, 40)        115360
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 20, 20, 40)        160
# _________________________________________________________________
# conv2d (Conv2D)              (None, 20, 20, 36)        1476
# =================================================================
# Total params: 226,900
# Trainable params: 226,668
# Non-trainable params: 232
# _________________________________________________________________

# %%
# due to time limitations, we will not do k-fold ensemble 
# fix the train and validation sets. 
train_files = [x for x in os.listdir('./storage/precipitation/train/')] 
train_files = shuffle(train_files)
k = int(0.8 * len(train_files)) 
train_data = train_files[:k]
val_data = train_files[k:]

partition = {'train':[], 'validation':[]} 

for filename in train_data: 
    partition['train'].append(filename) 
for filename in val_data: 
    partition['validation'].append(filename)  

params_train_gen = {'dim': (120,120),
                    'batch_size': 256,
                    'n_channels': 4,
                    'n_timesteps': 4,
                    'shuffle': True,
                    'augment_data': False}  

params_val_gen = {'dim': (120,120), 
                  'batch_size': 256, 
                  'n_channels': 4, 
                  'n_timesteps': 4,
                  'shuffle': True,
                  'augment_data': False} 
         

training_generator = DataGenerator(partition['train'], **params_train_gen)
validation_generator = DataGenerator(partition['validation'], **params_val_gen) 
model = simple_rnn()
        
model_path = './storage/precip_rnn_whole/epoch_{epoch:03d}_val_loss_{val_loss:.3f}.h5'
learning_rate_reduction = ReduceLROnPlateau(monitor = 'val_loss', patience = 3, verbose = 1, factor = 0.8)
checkpoint = ModelCheckpoint(filepath = model_path, monitor = 'val_loss', verbose = 1, save_best_only = True)
early_stopping = EarlyStopping(monitor = 'val_loss', patience = 16) 
history = model.fit_generator(generator = training_generator, validation_data = validation_generator, epochs = 300, callbacks = [checkpoint, early_stopping, learning_rate_reduction])
# Out:
# Epoch 1/300
# 195/196 [============================>.] - ETA: 0s - loss: 11.9068
# Epoch 00001: val_loss improved from inf to 12.59559, saving model to ./storage/precip_rnn_whole/epoch_001_val_loss_12.596.h5
# 196/196 [==============================] - 222s 1s/step - loss: 11.8981 - val_loss: 12.5956
# Epoch 2/300
# 195/196 [============================>.] - ETA: 0s - loss: 8.6239
# Epoch 00002: val_loss improved from 12.59559 to 9.85966, saving model to ./storage/precip_rnn_whole/epoch_002_val_loss_9.860.h5
# 196/196 [==============================] - 174s 885ms/step - loss: 8.6227 - val_loss: 9.8597
# Epoch 3/300
# 195/196 [============================>.] - ETA: 0s - loss: 6.8386
# Epoch 00003: val_loss improved from 9.85966 to 6.79659, saving model to ./storage/precip_rnn_whole/epoch_003_val_loss_6.797.h5
# 196/196 [==============================] - 192s 979ms/step - loss: 6.8375 - val_loss: 6.7966
# Epoch 4/300
# 195/196 [============================>.] - ETA: 0s - loss: 6.4744
# Epoch 00004: val_loss improved from 6.79659 to 6.29359, saving model to ./storage/precip_rnn_whole/epoch_004_val_loss_6.294.h5
# 196/196 [==============================] - 192s 980ms/step - loss: 6.4738 - val_loss: 6.2936
# Epoch 5/300
# 195/196 [============================>.] - ETA: 0s - loss: 5.9675
# Epoch 00005: val_loss improved from 6.29359 to 5.61057, saving model to ./storage/precip_rnn_whole/epoch_005_val_loss_5.611.h5
# 196/196 [==============================] - 194s 991ms/step - loss: 5.9652 - val_loss: 5.6106
# Epoch 6/300
# 195/196 [============================>.] - ETA: 0s - loss: 5.3580
# Epoch 00006: val_loss improved from 5.61057 to 5.13562, saving model to ./storage/precip_rnn_whole/epoch_006_val_loss_5.136.h5
# 196/196 [==============================] - 204s 1s/step - loss: 5.3579 - val_loss: 5.1356
# Epoch 7/300
# 195/196 [============================>.] - ETA: 0s - loss: 4.8858
# Epoch 00007: val_loss improved from 5.13562 to 4.79917, saving model to ./storage/precip_rnn_whole/epoch_007_val_loss_4.799.h5
# 196/196 [==============================] - 183s 936ms/step - loss: 4.8843 - val_loss: 4.7992
# Epoch 8/300
# 195/196 [============================>.] - ETA: 0s - loss: 4.5966
# Epoch 00008: val_loss improved from 4.79917 to 4.56318, saving model to ./storage/precip_rnn_whole/epoch_008_val_loss_4.563.h5
# 196/196 [==============================] - 176s 900ms/step - loss: 4.5961 - val_loss: 4.5632
# Epoch 9/300
# 195/196 [============================>.] - ETA: 0s - loss: 4.4352
# Epoch 00009: val_loss improved from 4.56318 to 4.35414, saving model to ./storage/precip_rnn_whole/epoch_009_val_loss_4.354.h5
# 196/196 [==============================] - 179s 912ms/step - loss: 4.4334 - val_loss: 4.3541
# Epoch 10/300
# 195/196 [============================>.] - ETA: 0s - loss: 4.2966
# Epoch 00010: val_loss improved from 4.35414 to 4.27914, saving model to ./storage/precip_rnn_whole/epoch_010_val_loss_4.279.h5
# 196/196 [==============================] - 176s 895ms/step - loss: 4.2978 - val_loss: 4.2791
# Epoch 11/300
# 195/196 [============================>.] - ETA: 0s - loss: 4.1965
# Epoch 00011: val_loss improved from 4.27914 to 4.17949, saving model to ./storage/precip_rnn_whole/epoch_011_val_loss_4.179.h5
# 196/196 [==============================] - 180s 918ms/step - loss: 4.1958 - val_loss: 4.1795
# Epoch 12/300
# 195/196 [============================>.] - ETA: 0s - loss: 4.1232
# Epoch 00012: val_loss improved from 4.17949 to 4.08385, saving model to ./storage/precip_rnn_whole/epoch_012_val_loss_4.084.h5
# 196/196 [==============================] - 171s 874ms/step - loss: 4.1233 - val_loss: 4.0838
# Epoch 13/300
# 195/196 [============================>.] - ETA: 0s - loss: 4.0561
# Epoch 00013: val_loss improved from 4.08385 to 4.07926, saving model to ./storage/precip_rnn_whole/epoch_013_val_loss_4.079.h5
# 196/196 [==============================] - 182s 930ms/step - loss: 4.0578 - val_loss: 4.0793
# Epoch 14/300
# 195/196 [============================>.] - ETA: 0s - loss: 4.0082
# Epoch 00014: val_loss improved from 4.07926 to 4.05111, saving model to ./storage/precip_rnn_whole/epoch_014_val_loss_4.051.h5
# 196/196 [==============================] - 183s 933ms/step - loss: 4.0072 - val_loss: 4.0511
# Epoch 15/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.9479
# Epoch 00015: val_loss improved from 4.05111 to 3.93957, saving model to ./storage/precip_rnn_whole/epoch_015_val_loss_3.940.h5
# 196/196 [==============================] - 173s 885ms/step - loss: 3.9470 - val_loss: 3.9396
# Epoch 16/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.9100
# Epoch 00016: val_loss improved from 3.93957 to 3.88851, saving model to ./storage/precip_rnn_whole/epoch_016_val_loss_3.889.h5
# 196/196 [==============================] - 163s 833ms/step - loss: 3.9088 - val_loss: 3.8885
# Epoch 17/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.8462
# Epoch 00017: val_loss did not improve from 3.88851
# 196/196 [==============================] - 168s 856ms/step - loss: 3.8455 - val_loss: 3.9018
# Epoch 18/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.8123
# Epoch 00018: val_loss did not improve from 3.88851
# 196/196 [==============================] - 163s 832ms/step - loss: 3.8126 - val_loss: 3.9758
# Epoch 19/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.8034
# Epoch 00019: val_loss improved from 3.88851 to 3.79857, saving model to ./storage/precip_rnn_whole/epoch_019_val_loss_3.799.h5
# 196/196 [==============================] - 164s 835ms/step - loss: 3.8041 - val_loss: 3.7986
# Epoch 20/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.7534
# Epoch 00020: val_loss improved from 3.79857 to 3.77930, saving model to ./storage/precip_rnn_whole/epoch_020_val_loss_3.779.h5
# 196/196 [==============================] - 165s 842ms/step - loss: 3.7523 - val_loss: 3.7793
# Epoch 21/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.7374
# Epoch 00021: val_loss did not improve from 3.77930
# 196/196 [==============================] - 166s 846ms/step - loss: 3.7366 - val_loss: 3.7838
# Epoch 22/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.7487
# Epoch 00022: val_loss improved from 3.77930 to 3.75258, saving model to ./storage/precip_rnn_whole/epoch_022_val_loss_3.753.h5
# 196/196 [==============================] - 164s 834ms/step - loss: 3.7496 - val_loss: 3.7526
# Epoch 23/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.7093
# Epoch 00023: val_loss did not improve from 3.75258
# 196/196 [==============================] - 165s 841ms/step - loss: 3.7091 - val_loss: 3.7889
# Epoch 24/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.7016
# Epoch 00024: val_loss improved from 3.75258 to 3.74085, saving model to ./storage/precip_rnn_whole/epoch_024_val_loss_3.741.h5
# 196/196 [==============================] - 168s 856ms/step - loss: 3.7030 - val_loss: 3.7408
# Epoch 25/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.6909
# Epoch 00025: val_loss improved from 3.74085 to 3.73785, saving model to ./storage/precip_rnn_whole/epoch_025_val_loss_3.738.h5
# 196/196 [==============================] - 165s 842ms/step - loss: 3.6896 - val_loss: 3.7379
# Epoch 26/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.6794
# Epoch 00026: val_loss improved from 3.73785 to 3.69936, saving model to ./storage/precip_rnn_whole/epoch_026_val_loss_3.699.h5
# 196/196 [==============================] - 168s 856ms/step - loss: 3.6803 - val_loss: 3.6994
# Epoch 27/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.6635
# Epoch 00027: val_loss did not improve from 3.69936
# 196/196 [==============================] - 168s 857ms/step - loss: 3.6619 - val_loss: 3.7095
# Epoch 28/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.6535
# Epoch 00028: val_loss improved from 3.69936 to 3.67950, saving model to ./storage/precip_rnn_whole/epoch_028_val_loss_3.680.h5
# 196/196 [==============================] - 166s 847ms/step - loss: 3.6529 - val_loss: 3.6795
# Epoch 29/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.6425
# Epoch 00029: val_loss did not improve from 3.67950
# 196/196 [==============================] - 167s 854ms/step - loss: 3.6438 - val_loss: 3.7093
# Epoch 30/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.6319
# Epoch 00030: val_loss improved from 3.67950 to 3.67288, saving model to ./storage/precip_rnn_whole/epoch_030_val_loss_3.673.h5
# 196/196 [==============================] - 166s 849ms/step - loss: 3.6322 - val_loss: 3.6729
# Epoch 31/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.6345
# Epoch 00031: val_loss did not improve from 3.67288
# 196/196 [==============================] - 167s 851ms/step - loss: 3.6347 - val_loss: 3.6794
# Epoch 32/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.6295
# Epoch 00032: val_loss improved from 3.67288 to 3.66018, saving model to ./storage/precip_rnn_whole/epoch_032_val_loss_3.660.h5
# 196/196 [==============================] - 166s 849ms/step - loss: 3.6302 - val_loss: 3.6602
# Epoch 33/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.6049
# Epoch 00033: val_loss improved from 3.66018 to 3.65283, saving model to ./storage/precip_rnn_whole/epoch_033_val_loss_3.653.h5
# 196/196 [==============================] - 166s 845ms/step - loss: 3.6069 - val_loss: 3.6528
# Epoch 34/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.6051
# Epoch 00034: val_loss improved from 3.65283 to 3.64510, saving model to ./storage/precip_rnn_whole/epoch_034_val_loss_3.645.h5
# 196/196 [==============================] - 167s 850ms/step - loss: 3.6053 - val_loss: 3.6451
# Epoch 35/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.6058
# Epoch 00035: val_loss did not improve from 3.64510
# 196/196 [==============================] - 166s 849ms/step - loss: 3.6048 - val_loss: 3.7047
# Epoch 36/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.6323
# Epoch 00036: val_loss did not improve from 3.64510
# 196/196 [==============================] - 164s 838ms/step - loss: 3.6316 - val_loss: 3.7080
# Epoch 37/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.5863
# Epoch 00037: val_loss improved from 3.64510 to 3.62197, saving model to ./storage/precip_rnn_whole/epoch_037_val_loss_3.622.h5
# 196/196 [==============================] - 169s 865ms/step - loss: 3.5855 - val_loss: 3.6220
# Epoch 38/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.5785
# Epoch 00038: val_loss did not improve from 3.62197
# 196/196 [==============================] - 166s 845ms/step - loss: 3.5784 - val_loss: 3.6416
# Epoch 39/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.5812
# Epoch 00039: val_loss did not improve from 3.62197
# 196/196 [==============================] - 167s 852ms/step - loss: 3.5806 - val_loss: 3.6544
# Epoch 40/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.5747
# Epoch 00040: val_loss improved from 3.62197 to 3.61002, saving model to ./storage/precip_rnn_whole/epoch_040_val_loss_3.610.h5
# 196/196 [==============================] - 167s 851ms/step - loss: 3.5742 - val_loss: 3.6100
# Epoch 41/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.5661
# Epoch 00041: val_loss did not improve from 3.61002
# 196/196 [==============================] - 167s 852ms/step - loss: 3.5659 - val_loss: 3.6383
# Epoch 42/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.5761
# Epoch 00042: val_loss did not improve from 3.61002
# 196/196 [==============================] - 165s 842ms/step - loss: 3.5751 - val_loss: 3.6293
# Epoch 43/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.5476
# Epoch 00043: val_loss improved from 3.61002 to 3.59741, saving model to ./storage/precip_rnn_whole/epoch_043_val_loss_3.597.h5
# 196/196 [==============================] - 166s 847ms/step - loss: 3.5490 - val_loss: 3.5974
# Epoch 44/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.5470
# Epoch 00044: val_loss improved from 3.59741 to 3.58285, saving model to ./storage/precip_rnn_whole/epoch_044_val_loss_3.583.h5
# 196/196 [==============================] - 168s 855ms/step - loss: 3.5447 - val_loss: 3.5828
# Epoch 45/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.5477
# Epoch 00045: val_loss did not improve from 3.58285
# 196/196 [==============================] - 166s 846ms/step - loss: 3.5477 - val_loss: 3.5882
# Epoch 46/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.5409
# Epoch 00046: val_loss improved from 3.58285 to 3.57997, saving model to ./storage/precip_rnn_whole/epoch_046_val_loss_3.580.h5
# 196/196 [==============================] - 163s 832ms/step - loss: 3.5428 - val_loss: 3.5800
# Epoch 47/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.5302
# Epoch 00047: val_loss did not improve from 3.57997
# 196/196 [==============================] - 167s 852ms/step - loss: 3.5314 - val_loss: 3.6015
# Epoch 48/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.5248
# Epoch 00048: val_loss did not improve from 3.57997
# 196/196 [==============================] - 167s 852ms/step - loss: 3.5257 - val_loss: 3.5847
# Epoch 49/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.5288
# Epoch 00049: val_loss did not improve from 3.57997
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# 196/196 [==============================] - 167s 851ms/step - loss: 3.5284 - val_loss: 3.6041
# Epoch 50/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.5146
# Epoch 00050: val_loss did not improve from 3.57997
# 196/196 [==============================] - 164s 837ms/step - loss: 3.5160 - val_loss: 3.5801
# Epoch 51/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.5151
# Epoch 00051: val_loss improved from 3.57997 to 3.56630, saving model to ./storage/precip_rnn_whole/epoch_051_val_loss_3.566.h5
# 196/196 [==============================] - 167s 851ms/step - loss: 3.5162 - val_loss: 3.5663
# Epoch 52/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.5007
# Epoch 00052: val_loss improved from 3.56630 to 3.54299, saving model to ./storage/precip_rnn_whole/epoch_052_val_loss_3.543.h5
# 196/196 [==============================] - 166s 845ms/step - loss: 3.5013 - val_loss: 3.5430
# Epoch 53/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.5099
# Epoch 00053: val_loss improved from 3.54299 to 3.54104, saving model to ./storage/precip_rnn_whole/epoch_053_val_loss_3.541.h5
# 196/196 [==============================] - 165s 843ms/step - loss: 3.5110 - val_loss: 3.5410
# Epoch 54/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.5034
# Epoch 00054: val_loss did not improve from 3.54104
# 196/196 [==============================] - 168s 857ms/step - loss: 3.5026 - val_loss: 3.5781
# Epoch 55/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.5063
# Epoch 00055: val_loss did not improve from 3.54104
# 196/196 [==============================] - 166s 848ms/step - loss: 3.5054 - val_loss: 3.5473
# Epoch 56/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4944
# Epoch 00056: val_loss did not improve from 3.54104
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# 196/196 [==============================] - 165s 840ms/step - loss: 3.4927 - val_loss: 3.5775
# Epoch 57/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4865
# Epoch 00057: val_loss improved from 3.54104 to 3.53367, saving model to ./storage/precip_rnn_whole/epoch_057_val_loss_3.534.h5
# 196/196 [==============================] - 166s 849ms/step - loss: 3.4858 - val_loss: 3.5337
# Epoch 58/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4793
# Epoch 00058: val_loss did not improve from 3.53367
# 196/196 [==============================] - 165s 843ms/step - loss: 3.4793 - val_loss: 3.5355
# Epoch 59/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4828
# Epoch 00059: val_loss improved from 3.53367 to 3.52116, saving model to ./storage/precip_rnn_whole/epoch_059_val_loss_3.521.h5
# 196/196 [==============================] - 165s 844ms/step - loss: 3.4830 - val_loss: 3.5212
# Epoch 60/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4795
# Epoch 00060: val_loss did not improve from 3.52116
# 196/196 [==============================] - 166s 847ms/step - loss: 3.4801 - val_loss: 3.5246
# Epoch 61/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4880
# Epoch 00061: val_loss did not improve from 3.52116
# 196/196 [==============================] - 165s 840ms/step - loss: 3.4879 - val_loss: 3.5424
# Epoch 62/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4781
# Epoch 00062: val_loss did not improve from 3.52116
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
# 196/196 [==============================] - 164s 836ms/step - loss: 3.4769 - val_loss: 3.5243
# Epoch 63/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4665
# Epoch 00063: val_loss improved from 3.52116 to 3.51792, saving model to ./storage/precip_rnn_whole/epoch_063_val_loss_3.518.h5
# 196/196 [==============================] - 166s 849ms/step - loss: 3.4664 - val_loss: 3.5179
# Epoch 64/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4699
# Epoch 00064: val_loss improved from 3.51792 to 3.51422, saving model to ./storage/precip_rnn_whole/epoch_064_val_loss_3.514.h5
# 196/196 [==============================] - 169s 863ms/step - loss: 3.4684 - val_loss: 3.5142
# Epoch 65/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4611
# Epoch 00065: val_loss did not improve from 3.51422
# 196/196 [==============================] - 167s 854ms/step - loss: 3.4613 - val_loss: 3.5148
# Epoch 66/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4646
# Epoch 00066: val_loss improved from 3.51422 to 3.50752, saving model to ./storage/precip_rnn_whole/epoch_066_val_loss_3.508.h5
# 196/196 [==============================] - 164s 838ms/step - loss: 3.4651 - val_loss: 3.5075
# Epoch 67/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4631
# Epoch 00067: val_loss improved from 3.50752 to 3.49959, saving model to ./storage/precip_rnn_whole/epoch_067_val_loss_3.500.h5
# 196/196 [==============================] - 167s 854ms/step - loss: 3.4616 - val_loss: 3.4996
# Epoch 68/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4597
# Epoch 00068: val_loss did not improve from 3.49959
# 196/196 [==============================] - 166s 848ms/step - loss: 3.4609 - val_loss: 3.5055
# Epoch 69/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4569
# Epoch 00069: val_loss did not improve from 3.49959
# 196/196 [==============================] - 164s 836ms/step - loss: 3.4565 - val_loss: 3.5004
# Epoch 70/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4563
# Epoch 00070: val_loss improved from 3.49959 to 3.49832, saving model to ./storage/precip_rnn_whole/epoch_070_val_loss_3.498.h5
# 196/196 [==============================] - 163s 832ms/step - loss: 3.4543 - val_loss: 3.4983
# Epoch 71/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4585
# Epoch 00071: val_loss improved from 3.49832 to 3.49795, saving model to ./storage/precip_rnn_whole/epoch_071_val_loss_3.498.h5
# 196/196 [==============================] - 166s 848ms/step - loss: 3.4590 - val_loss: 3.4980
# Epoch 72/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4548
# Epoch 00072: val_loss did not improve from 3.49795
# 196/196 [==============================] - 164s 837ms/step - loss: 3.4536 - val_loss: 3.5039
# Epoch 73/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4512
# Epoch 00073: val_loss did not improve from 3.49795
# 196/196 [==============================] - 166s 848ms/step - loss: 3.4516 - val_loss: 3.5063
# Epoch 74/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4488
# Epoch 00074: val_loss did not improve from 3.49795
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
# 196/196 [==============================] - 171s 870ms/step - loss: 3.4496 - val_loss: 3.4989
# Epoch 75/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4452
# Epoch 00075: val_loss improved from 3.49795 to 3.49711, saving model to ./storage/precip_rnn_whole/epoch_075_val_loss_3.497.h5
# 196/196 [==============================] - 168s 858ms/step - loss: 3.4443 - val_loss: 3.4971
# Epoch 76/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4414
# Epoch 00076: val_loss did not improve from 3.49711
# 196/196 [==============================] - 167s 854ms/step - loss: 3.4405 - val_loss: 3.5083
# Epoch 77/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4397
# Epoch 00077: val_loss improved from 3.49711 to 3.48696, saving model to ./storage/precip_rnn_whole/epoch_077_val_loss_3.487.h5
# 196/196 [==============================] - 192s 977ms/step - loss: 3.4404 - val_loss: 3.4870
# Epoch 78/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4459
# Epoch 00078: val_loss improved from 3.48696 to 3.48426, saving model to ./storage/precip_rnn_whole/epoch_078_val_loss_3.484.h5
# 196/196 [==============================] - 178s 907ms/step - loss: 3.4453 - val_loss: 3.4843
# Epoch 79/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4370
# Epoch 00079: val_loss did not improve from 3.48426
# 196/196 [==============================] - 170s 865ms/step - loss: 3.4390 - val_loss: 3.5026
# Epoch 80/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4399
# Epoch 00080: val_loss improved from 3.48426 to 3.48075, saving model to ./storage/precip_rnn_whole/epoch_080_val_loss_3.481.h5
# 196/196 [==============================] - 169s 860ms/step - loss: 3.4389 - val_loss: 3.4807
# Epoch 81/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4394
# Epoch 00081: val_loss did not improve from 3.48075
# 196/196 [==============================] - 167s 855ms/step - loss: 3.4392 - val_loss: 3.4920
# Epoch 82/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4339
# Epoch 00082: val_loss did not improve from 3.48075
# 196/196 [==============================] - 166s 846ms/step - loss: 3.4349 - val_loss: 3.4997
# Epoch 83/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4344
# Epoch 00083: val_loss did not improve from 3.48075
#
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
# 196/196 [==============================] - 166s 849ms/step - loss: 3.4348 - val_loss: 3.4860
# Epoch 84/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4294
# Epoch 00084: val_loss did not improve from 3.48075
# 196/196 [==============================] - 167s 853ms/step - loss: 3.4287 - val_loss: 3.4848
# Epoch 85/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4372
# Epoch 00085: val_loss improved from 3.48075 to 3.47396, saving model to ./storage/precip_rnn_whole/epoch_085_val_loss_3.474.h5
# 196/196 [==============================] - 168s 858ms/step - loss: 3.4360 - val_loss: 3.4740
# Epoch 86/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4294
# Epoch 00086: val_loss did not improve from 3.47396
# 196/196 [==============================] - 165s 840ms/step - loss: 3.4290 - val_loss: 3.4781
# Epoch 87/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4327
# Epoch 00087: val_loss improved from 3.47396 to 3.47027, saving model to ./storage/precip_rnn_whole/epoch_087_val_loss_3.470.h5
# 196/196 [==============================] - 166s 849ms/step - loss: 3.4313 - val_loss: 3.4703
# Epoch 88/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4295
# Epoch 00088: val_loss did not improve from 3.47027
# 196/196 [==============================] - 165s 841ms/step - loss: 3.4299 - val_loss: 3.4735
# Epoch 89/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4303
# Epoch 00089: val_loss did not improve from 3.47027
# 196/196 [==============================] - 163s 830ms/step - loss: 3.4288 - val_loss: 3.4920
# Epoch 90/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4280
# Epoch 00090: val_loss did not improve from 3.47027
#
# Epoch 00090: ReduceLROnPlateau reducing learning rate to 0.0002621440216898918.
# 196/196 [==============================] - 173s 880ms/step - loss: 3.4278 - val_loss: 3.4814
# Epoch 91/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4228
# Epoch 00091: val_loss did not improve from 3.47027
# 196/196 [==============================] - 170s 868ms/step - loss: 3.4238 - val_loss: 3.4784
# Epoch 92/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4205
# Epoch 00092: val_loss did not improve from 3.47027
# 196/196 [==============================] - 165s 841ms/step - loss: 3.4209 - val_loss: 3.4744
# Epoch 93/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4189
# Epoch 00093: val_loss did not improve from 3.47027
#
# Epoch 00093: ReduceLROnPlateau reducing learning rate to 0.00020971521735191345.
# 196/196 [==============================] - 164s 835ms/step - loss: 3.4202 - val_loss: 3.4742
# Epoch 94/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4224
# Epoch 00094: val_loss did not improve from 3.47027
# 196/196 [==============================] - 169s 861ms/step - loss: 3.4213 - val_loss: 3.4726
# Epoch 95/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4174
# Epoch 00095: val_loss improved from 3.47027 to 3.46299, saving model to ./storage/precip_rnn_whole/epoch_095_val_loss_3.463.h5
# 196/196 [==============================] - 164s 838ms/step - loss: 3.4175 - val_loss: 3.4630
# Epoch 96/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4180
# Epoch 00096: val_loss did not improve from 3.46299
# 196/196 [==============================] - 165s 843ms/step - loss: 3.4183 - val_loss: 3.4785
# Epoch 97/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4178
# Epoch 00097: val_loss improved from 3.46299 to 3.46019, saving model to ./storage/precip_rnn_whole/epoch_097_val_loss_3.460.h5
# 196/196 [==============================] - 167s 850ms/step - loss: 3.4167 - val_loss: 3.4602
# Epoch 98/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4187
# Epoch 00098: val_loss did not improve from 3.46019
# 196/196 [==============================] - 171s 874ms/step - loss: 3.4187 - val_loss: 3.4633
# Epoch 99/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4181
# Epoch 00099: val_loss did not improve from 3.46019
# 196/196 [==============================] - 176s 898ms/step - loss: 3.4180 - val_loss: 3.4753
# Epoch 100/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4166
# Epoch 00100: val_loss did not improve from 3.46019
#
# Epoch 00100: ReduceLROnPlateau reducing learning rate to 0.00016777217388153076.
# 196/196 [==============================] - 191s 975ms/step - loss: 3.4164 - val_loss: 3.4652
# Epoch 101/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4128
# Epoch 00101: val_loss did not improve from 3.46019
# 196/196 [==============================] - 188s 958ms/step - loss: 3.4136 - val_loss: 3.4645
# Epoch 102/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4095
# Epoch 00102: val_loss did not improve from 3.46019
# 196/196 [==============================] - 183s 932ms/step - loss: 3.4104 - val_loss: 3.4611
# Epoch 103/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4131
# Epoch 00103: val_loss did not improve from 3.46019
#
# Epoch 00103: ReduceLROnPlateau reducing learning rate to 0.00013421773910522462.
# 196/196 [==============================] - 199s 1s/step - loss: 3.4129 - val_loss: 3.4625
# Epoch 104/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4112
# Epoch 00104: val_loss improved from 3.46019 to 3.45799, saving model to ./storage/precip_rnn_whole/epoch_104_val_loss_3.458.h5
# 196/196 [==============================] - 214s 1s/step - loss: 3.4101 - val_loss: 3.4580
# Epoch 105/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4088
# Epoch 00105: val_loss improved from 3.45799 to 3.45705, saving model to ./storage/precip_rnn_whole/epoch_105_val_loss_3.457.h5
# 196/196 [==============================] - 178s 906ms/step - loss: 3.4099 - val_loss: 3.4571
# Epoch 106/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4074
# Epoch 00106: val_loss did not improve from 3.45705
# 196/196 [==============================] - 167s 854ms/step - loss: 3.4088 - val_loss: 3.4613
# Epoch 107/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4097
# Epoch 00107: val_loss improved from 3.45705 to 3.45389, saving model to ./storage/precip_rnn_whole/epoch_107_val_loss_3.454.h5
# 196/196 [==============================] - 168s 858ms/step - loss: 3.4095 - val_loss: 3.4539
# Epoch 108/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4148
# Epoch 00108: val_loss did not improve from 3.45389
# 196/196 [==============================] - 166s 847ms/step - loss: 3.4127 - val_loss: 3.4575
# Epoch 109/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4093
# Epoch 00109: val_loss did not improve from 3.45389
# 196/196 [==============================] - 162s 826ms/step - loss: 3.4090 - val_loss: 3.4585
# Epoch 110/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4064
# Epoch 00110: val_loss did not improve from 3.45389
#
# Epoch 00110: ReduceLROnPlateau reducing learning rate to 0.00010737419361248613.
# 196/196 [==============================] - 169s 861ms/step - loss: 3.4080 - val_loss: 3.4627
# Epoch 111/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4088
# Epoch 00111: val_loss did not improve from 3.45389
# 196/196 [==============================] - 165s 843ms/step - loss: 3.4077 - val_loss: 3.4541
# Epoch 112/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4044
# Epoch 00112: val_loss improved from 3.45389 to 3.45281, saving model to ./storage/precip_rnn_whole/epoch_112_val_loss_3.453.h5
# 196/196 [==============================] - 165s 841ms/step - loss: 3.4053 - val_loss: 3.4528
# Epoch 113/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4067
# Epoch 00113: val_loss did not improve from 3.45281
# 196/196 [==============================] - 169s 860ms/step - loss: 3.4061 - val_loss: 3.4547
# Epoch 114/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4036
# Epoch 00114: val_loss did not improve from 3.45281
# 196/196 [==============================] - 168s 855ms/step - loss: 3.4047 - val_loss: 3.4554
# Epoch 115/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4059
# Epoch 00115: val_loss did not improve from 3.45281
#
# Epoch 00115: ReduceLROnPlateau reducing learning rate to 8.589935605414213e-05.
# 196/196 [==============================] - 166s 849ms/step - loss: 3.4058 - val_loss: 3.4543
# Epoch 116/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4034
# Epoch 00116: val_loss did not improve from 3.45281
# 196/196 [==============================] - 166s 846ms/step - loss: 3.4035 - val_loss: 3.4745
# Epoch 117/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4054
# Epoch 00117: val_loss did not improve from 3.45281
# 196/196 [==============================] - 170s 866ms/step - loss: 3.4047 - val_loss: 3.4540
# Epoch 118/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4016
# Epoch 00118: val_loss did not improve from 3.45281
#
# Epoch 00118: ReduceLROnPlateau reducing learning rate to 6.871948717162013e-05.
# 196/196 [==============================] - 166s 848ms/step - loss: 3.4026 - val_loss: 3.4546
# Epoch 119/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4032
# Epoch 00119: val_loss improved from 3.45281 to 3.45148, saving model to ./storage/precip_rnn_whole/epoch_119_val_loss_3.451.h5
# 196/196 [==============================] - 166s 849ms/step - loss: 3.4028 - val_loss: 3.4515
# Epoch 120/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4020
# Epoch 00120: val_loss improved from 3.45148 to 3.45067, saving model to ./storage/precip_rnn_whole/epoch_120_val_loss_3.451.h5
# 196/196 [==============================] - 171s 871ms/step - loss: 3.4018 - val_loss: 3.4507
# Epoch 121/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4015
# Epoch 00121: val_loss did not improve from 3.45067
# 196/196 [==============================] - 170s 867ms/step - loss: 3.4016 - val_loss: 3.4524
# Epoch 122/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4006
# Epoch 00122: val_loss improved from 3.45067 to 3.45017, saving model to ./storage/precip_rnn_whole/epoch_122_val_loss_3.450.h5
# 196/196 [==============================] - 167s 854ms/step - loss: 3.4016 - val_loss: 3.4502
# Epoch 123/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4018
# Epoch 00123: val_loss improved from 3.45017 to 3.44928, saving model to ./storage/precip_rnn_whole/epoch_123_val_loss_3.449.h5
# 196/196 [==============================] - 168s 856ms/step - loss: 3.4016 - val_loss: 3.4493
# Epoch 124/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4013
# Epoch 00124: val_loss did not improve from 3.44928
# 196/196 [==============================] - 168s 858ms/step - loss: 3.4010 - val_loss: 3.4520
# Epoch 125/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4011
# Epoch 00125: val_loss did not improve from 3.44928
# 196/196 [==============================] - 168s 857ms/step - loss: 3.4004 - val_loss: 3.4545
# Epoch 126/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4013
# Epoch 00126: val_loss improved from 3.44928 to 3.44834, saving model to ./storage/precip_rnn_whole/epoch_126_val_loss_3.448.h5
# 196/196 [==============================] - 165s 843ms/step - loss: 3.4014 - val_loss: 3.4483
# Epoch 127/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4009
# Epoch 00127: val_loss did not improve from 3.44834
# 196/196 [==============================] - 166s 847ms/step - loss: 3.4002 - val_loss: 3.4490
# Epoch 128/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4017
# Epoch 00128: val_loss did not improve from 3.44834
# 196/196 [==============================] - 170s 869ms/step - loss: 3.4013 - val_loss: 3.4488
# Epoch 129/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4004
# Epoch 00129: val_loss did not improve from 3.44834
#
# Epoch 00129: ReduceLROnPlateau reducing learning rate to 5.497558740898967e-05.
# 196/196 [==============================] - 167s 852ms/step - loss: 3.4013 - val_loss: 3.4530
# Epoch 130/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3995
# Epoch 00130: val_loss did not improve from 3.44834
# 196/196 [==============================] - 166s 847ms/step - loss: 3.3994 - val_loss: 3.4504
# Epoch 131/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4009
# Epoch 00131: val_loss did not improve from 3.44834
# 196/196 [==============================] - 167s 853ms/step - loss: 3.4000 - val_loss: 3.4570
# Epoch 132/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4004
# Epoch 00132: val_loss improved from 3.44834 to 3.44756, saving model to ./storage/precip_rnn_whole/epoch_132_val_loss_3.448.h5
# 196/196 [==============================] - 169s 860ms/step - loss: 3.4006 - val_loss: 3.4476
# Epoch 133/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4004
# Epoch 00133: val_loss did not improve from 3.44756
# 196/196 [==============================] - 168s 859ms/step - loss: 3.3984 - val_loss: 3.4557
# Epoch 134/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3999
# Epoch 00134: val_loss did not improve from 3.44756
# 196/196 [==============================] - 166s 847ms/step - loss: 3.3991 - val_loss: 3.4485
# Epoch 135/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.4004
# Epoch 00135: val_loss did not improve from 3.44756
#
# Epoch 00135: ReduceLROnPlateau reducing learning rate to 4.398046876303852e-05.
# 196/196 [==============================] - 168s 858ms/step - loss: 3.3997 - val_loss: 3.4494
# Epoch 136/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3977
# Epoch 00136: val_loss did not improve from 3.44756
# 196/196 [==============================] - 170s 867ms/step - loss: 3.3980 - val_loss: 3.4484
# Epoch 137/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3973
# Epoch 00137: val_loss did not improve from 3.44756
# 196/196 [==============================] - 166s 846ms/step - loss: 3.3982 - val_loss: 3.4487
# Epoch 138/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3967
# Epoch 00138: val_loss did not improve from 3.44756
#
# Epoch 00138: ReduceLROnPlateau reducing learning rate to 3.518437442835421e-05.
# 196/196 [==============================] - 166s 849ms/step - loss: 3.3956 - val_loss: 3.4507
# Epoch 139/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3977
# Epoch 00139: val_loss did not improve from 3.44756
# 196/196 [==============================] - 168s 856ms/step - loss: 3.3979 - val_loss: 3.4515
# Epoch 140/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3971
# Epoch 00140: val_loss did not improve from 3.44756
# 196/196 [==============================] - 170s 867ms/step - loss: 3.3986 - val_loss: 3.4493
# Epoch 141/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3996
# Epoch 00141: val_loss did not improve from 3.44756
#
# Epoch 00141: ReduceLROnPlateau reducing learning rate to 2.8147498960606756e-05.
# 196/196 [==============================] - 168s 855ms/step - loss: 3.3998 - val_loss: 3.4479
# Epoch 142/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3958
# Epoch 00142: val_loss did not improve from 3.44756
# 196/196 [==============================] - 166s 849ms/step - loss: 3.3978 - val_loss: 3.4492
# Epoch 143/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3980
# Epoch 00143: val_loss improved from 3.44756 to 3.44667, saving model to ./storage/precip_rnn_whole/epoch_143_val_loss_3.447.h5
# 196/196 [==============================] - 169s 862ms/step - loss: 3.3968 - val_loss: 3.4467
# Epoch 144/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3970
# Epoch 00144: val_loss did not improve from 3.44667
# 196/196 [==============================] - 169s 860ms/step - loss: 3.3968 - val_loss: 3.4469
# Epoch 145/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3952
# Epoch 00145: val_loss improved from 3.44667 to 3.44565, saving model to ./storage/precip_rnn_whole/epoch_145_val_loss_3.446.h5
# 196/196 [==============================] - 175s 893ms/step - loss: 3.3961 - val_loss: 3.4456
# Epoch 146/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3949
# Epoch 00146: val_loss did not improve from 3.44565
# 196/196 [==============================] - 172s 876ms/step - loss: 3.3955 - val_loss: 3.4462
# Epoch 147/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3951
# Epoch 00147: val_loss did not improve from 3.44565
# 196/196 [==============================] - 169s 860ms/step - loss: 3.3970 - val_loss: 3.4485
# Epoch 148/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3966
# Epoch 00148: val_loss did not improve from 3.44565
#
# Epoch 00148: ReduceLROnPlateau reducing learning rate to 2.25179988774471e-05.
# 196/196 [==============================] - 169s 864ms/step - loss: 3.3954 - val_loss: 3.4484
# Epoch 149/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3965
# Epoch 00149: val_loss did not improve from 3.44565
# 196/196 [==============================] - 167s 853ms/step - loss: 3.3957 - val_loss: 3.4466
# Epoch 150/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3959
# Epoch 00150: val_loss improved from 3.44565 to 3.44322, saving model to ./storage/precip_rnn_whole/epoch_150_val_loss_3.443.h5
# 196/196 [==============================] - 169s 863ms/step - loss: 3.3960 - val_loss: 3.4432
# Epoch 151/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3957
# Epoch 00151: val_loss did not improve from 3.44322
# 196/196 [==============================] - 170s 866ms/step - loss: 3.3953 - val_loss: 3.4454
# Epoch 152/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3955
# Epoch 00152: val_loss did not improve from 3.44322
# 196/196 [==============================] - 166s 848ms/step - loss: 3.3943 - val_loss: 3.4455
# Epoch 153/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3959
# Epoch 00153: val_loss did not improve from 3.44322
#
# Epoch 00153: ReduceLROnPlateau reducing learning rate to 1.8014399392995985e-05.
# 196/196 [==============================] - 166s 848ms/step - loss: 3.3958 - val_loss: 3.4456
# Epoch 154/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3962
# Epoch 00154: val_loss did not improve from 3.44322
# 196/196 [==============================] - 169s 863ms/step - loss: 3.3959 - val_loss: 3.4462
# Epoch 155/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3962
# Epoch 00155: val_loss did not improve from 3.44322
# 196/196 [==============================] - 171s 873ms/step - loss: 3.3950 - val_loss: 3.4449
# Epoch 156/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3970
# Epoch 00156: val_loss did not improve from 3.44322
#
# Epoch 00156: ReduceLROnPlateau reducing learning rate to 1.4411519805435093e-05.
# 196/196 [==============================] - 172s 877ms/step - loss: 3.3957 - val_loss: 3.4462
# Epoch 157/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3947
# Epoch 00157: val_loss did not improve from 3.44322
# 196/196 [==============================] - 167s 852ms/step - loss: 3.3950 - val_loss: 3.4454
# Epoch 158/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3939
# Epoch 00158: val_loss did not improve from 3.44322
# 196/196 [==============================] - 168s 857ms/step - loss: 3.3947 - val_loss: 3.4453
# Epoch 159/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3967
# Epoch 00159: val_loss did not improve from 3.44322
#
# Epoch 00159: ReduceLROnPlateau reducing learning rate to 1.1529216135386379e-05.
# 196/196 [==============================] - 167s 854ms/step - loss: 3.3962 - val_loss: 3.4487
# Epoch 160/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3950
# Epoch 00160: val_loss did not improve from 3.44322
# 196/196 [==============================] - 166s 849ms/step - loss: 3.3947 - val_loss: 3.4458
# Epoch 161/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3956
# Epoch 00161: val_loss did not improve from 3.44322
# 196/196 [==============================] - 166s 847ms/step - loss: 3.3937 - val_loss: 3.4445
# Epoch 162/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3954
# Epoch 00162: val_loss did not improve from 3.44322
#
# Epoch 00162: ReduceLROnPlateau reducing learning rate to 9.223372762789951e-06.
# 196/196 [==============================] - 167s 852ms/step - loss: 3.3942 - val_loss: 3.4450
# Epoch 163/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3957
# Epoch 00163: val_loss did not improve from 3.44322
# 196/196 [==============================] - 169s 860ms/step - loss: 3.3948 - val_loss: 3.4443
# Epoch 164/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3930
# Epoch 00164: val_loss did not improve from 3.44322
# 196/196 [==============================] - 168s 860ms/step - loss: 3.3940 - val_loss: 3.4438
# Epoch 165/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3939
# Epoch 00165: val_loss did not improve from 3.44322
#
# Epoch 00165: ReduceLROnPlateau reducing learning rate to 7.378698501270265e-06.
# 196/196 [==============================] - 167s 850ms/step - loss: 3.3936 - val_loss: 3.4439
# Epoch 166/300
# 195/196 [============================>.] - ETA: 0s - loss: 3.3942
# Epoch 00166: val_loss did not improve from 3.44322
# 196/196 [==============================] - 166s 849ms/step - loss: 3.3949 - val_loss: 3.4445
